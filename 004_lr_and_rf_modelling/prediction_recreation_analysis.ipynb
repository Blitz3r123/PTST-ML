# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # All Predictions

# %%
from prediction_recreation_analysis_functions import *

for METRIC in ['latency_us']:
    # ? Linear Regression Interpolation
    # model_json, model = get_model_info_from_metric("lr", True, METRIC)
    # predict_random_test_for_metric(model_json, model, METRIC, 5)
    # predict_random_tests_for_metric_with_gridspace_location(model_json, model, METRIC, 5)

    # # ? Linear Regression Extrapolation
    # model_json, model = get_model_info_from_metric("lr", False, METRIC)
    # predict_random_test_for_metric(model_json, model, METRIC, 5)
    # predict_random_tests_for_metric_with_gridspace_location(model_json, model, METRIC, 5)

    # # ? Random Forests Interpolation
    # model_json, model = get_model_info_from_metric("rf", True, METRIC)
    # predict_random_test_for_metric(model_json, model, METRIC, 5)
    # predict_random_tests_for_metric_with_gridspace_location(model_json, model, METRIC, 5)

    # # ? Random Forests Extrapolation
    model_json, model = get_model_info_from_metric("rf", False, METRIC)
    predict_random_test_for_metric(model_json, model, METRIC, 5)
    predict_random_tests_for_metric_with_gridspace_location(model_json, model, METRIC, 5)
