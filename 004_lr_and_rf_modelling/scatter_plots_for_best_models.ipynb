# %%
# %load_ext autoreload
# %autoreload 2

# %%
from scatter_plots_for_best_models_functions import *

for METRIC in METRICS:
    model_json, model = get_best_model_for_metric(METRIC)
    predict_random_test_for_metric(model_json, model, METRIC, 4, 'cdf')
